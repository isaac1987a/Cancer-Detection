# %%
import numpy as np
import pandas as pd
from PIL import Image
import random
import keras
import h5py
import matplotlib.pyplot as plt
import bz2
import zipfile
import requests
import os
import gc
import timeit
# Out:
# 2024-03-26 20:35:31.556575: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 20:35:31.556626: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 20:35:31.558072: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-26 20:35:31.566235: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Import the labels
input_directory = "kaggle/input/histopathologic-cancer-detection/"
working_directory = "kaggle/working/"
tmp_directory = "kaggle/temp"

# %%
def download_file(url, folder_path, local_filename):
    # Make a request to the URL
    response = requests.get(url)
    response.raise_for_status()  # Raise an error for bad responses

    # Create the full path to the file
    file_path = os.path.join(folder_path, local_filename)

    # Write the file content in binary mode to the specified folder
    with open(file_path, 'wb') as file:
        file.write(response.content)

# %%
#Download Kaggle File
url = 'https://storage.googleapis.com/isaac_blach_ml_storage/histopathologic-cancer-detection.zip'
folder_path = input_directory
local_filename = 'histopathologic-cancer-detection.zip'

download_file(url, folder_path, local_filename)

# %%
with zipfile.ZipFile(input_directory + "histopathologic-cancer-detection.zip", 'r') as zip_ref:
    zip_ref.extractall(input_directory)

# %%
directory = input_directory + "train_labels.csv"
images = pd.read_csv(directory)
images.head()
# Out:
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      0
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0

# %%
#print random images with lablels
samples = images.iloc[random.sample(range(0,images.shape[0]), 10)]
#print(samples)
for sample in samples.iterrows():
    #print(sample[1])
    path = input_directory + "train/" + str(sample[1]["id"]) + ".tif"
    if sample[1]["label"] == 0:
        print("Cancer Free")
    else:
        print("Cancerous")
    im = Image.open(path)
    display(im)
# Out:
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancerous
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>
# Cancer Free
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96>

# %% [markdown]
# ## EDA
# - Cancerous vs Cancer Free numbers in train set
# - Size of set
# - Find more later

# %%
#GPT assisted class

def load_and_process_image(filename):
    path=input_directory + "train/" + filename + ".tif"
    im = keras.utils.load_img(path, color_mode='rgb', target_size=(32,32))
    return keras.utils.img_to_array(im)/255
#Build Rotations


images['image_data'] = images['id'].apply(load_and_process_image)

# %%
# Store the results in a file for faster loading
X = np.stack(images['image_data'].values)
y = images['label'].values
path = working_directory + 'image_data.h5'
hdf5_file = path

with h5py.File(hdf5_file, 'w') as f:
    f.create_dataset('images', data=X)
    f.create_dataset('labels', data=y)

# %%
#BZ2 Compress for cloud storage
with open(working_directory + "image_data.h5", 'rb') as input_file:
    with bz2.open(working_directory + "image_data.bz2", 'wb', compresslevel=9) as output_file:
        output_file.writelines(input_file)

# %% [markdown]
# ## Expanding the training set
#
# A good pratice in trianing image data is to rotate and shift the training set to create a better and more complete training set.  In researching this problem, just rotating all the images can create a 5% increase in accuracy if properly tuned.

# %%
# Download images non-rotated
url = 'https://storage.googleapis.com/isaac_blach_ml_storage/image_data.bz2'
folder_path = working_directory
local_filename = 'image_data.bz2'

download_file(url, folder_path, local_filename)

#unbz2 images for git storage
with bz2.open(working_directory + "image_data.bz2", 'rb') as compressed_file:
    with open(working_directory + "image_data.h5", 'wb') as decompressed_file:
        # Copy the decompressed data to a new file
        decompressed_file.write(compressed_file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 6
#       3 folder_path = working_directory
#       4 local_filename = 'image_data.bz2'
# ----> 6 download_file(url, folder_path, local_filename)
#       8 #unbz2 images for git storage
#       9 with bz2.open(working_directory + "image_data.bz2", 'rb') as compressed_file:
#
# Cell In[15], line 10, in download_file(url, folder_path, local_filename)
#       7 file_path = os.path.join(folder_path, local_filename)
#       9 # Write the file content in binary mode to the specified folder
# ---> 10 with open(file_path, 'wb') as file:
#      11     file.write(response.content)
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/image_data.bz2'

# %%
# Load dataset from file
path = working_directory + 'image_data.h5'
hdf5_file = path
with h5py.File(hdf5_file, 'r') as f:
    # Load the datasets back into memory
    X = f['images'][:]
    y = f['labels'][:]

# %%
# Rotate Images

def rotate_images(images, k):
    return np.rot90(images, k=k, axes = (1,2))

X_rotated = np.concatenate((X, rotate_images(X, 1), rotate_images(X, 2), rotate_images(X, 3)))
y_rotated = np.concatenate((y,y,y,y))

print("X Shape: " + str(X.shape))
print("X Rotated Shape: " + str(X_rotated.shape))
print("y Shape: " + str(y.shape))
print("y Shape: " + str(y_rotated.shape))
# Out:
# X Shape: (220025, 32, 32, 3)
# X Rotated Shape: (880100, 32, 32, 3)
# y Shape: (220025,)
# y Shape: (880100,)

# %%
# Developed with help from https://keras.io/api/models/model/

def convolution_block(inputs, filters, activation = "ReLU"):
    filters = filters
    kernel_size=(3,3)
    conv1 = keras.layers.Conv2D(
        filters,
        kernel_size,
        strides=(1, 1),
        padding="valid",
        data_format=None,
        dilation_rate=(1, 1),
        groups=1,
        activation=activation,
        use_bias=True,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        activity_regularizer=None,
        kernel_constraint=None,
        bias_constraint=None,
    ) (inputs)
    return conv1

def pool_block(inputs):
    pool = keras.layers.MaxPooling2D(
        pool_size=(2, 2), strides=None, padding="valid", data_format=None, name=None
    )(inputs)
    return pool

def dropout_block(inputs, dropout_value):
    dropout = keras.layers.Dropout(dropout_value)(inputs)
    return dropout

def activation_block(inputs, layer_density): 
    dense = keras.layers.Dense(layer_density, activation='relu') (inputs)
    return dense

def prep_one_block():
    dropout_value = .25
    inputs = keras.Input(shape=(32,32,3))
    convolution = inputs
    for i in range(0,1):
        convolution = convolution_block(convolution, 32)
        convolution = convolution_block(convolution, 32)
        convolution = pool_block(convolution)
        
    flatten= keras.layers.Flatten()(convolution)

    activation = flatten
    for i in range(0,1):
        activation = activation_block(activation,1024)
        activation = dropout_block(activation, dropout_value)
    outputs = keras.layers.Dense(1, activation="sigmoid")(activation)
    full_model = keras.Model(inputs, outputs)
    return full_model

# %%
def run_model(full_model, learning_rate, X, y, epochs = 10):
    
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    full_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[keras.metrics.BinaryAccuracy()])
    history = full_model.fit(
        x=X,
        y=y,
        batch_size=64,
        epochs=epochs,
        verbose=0,
        callbacks=None,
        validation_split=0.2,
        validation_data=None,
        shuffle=True,
        class_weight=None,
        sample_weight=None,
        initial_epoch=0,
        steps_per_epoch=None,
        validation_steps=None,
    validation_batch_size=None,
    validation_freq=1,
    )
    return full_model, history

# %%
# Stolen Shamelessly from https://github.com/keras-team/keras/issues/12625 
# Clears up GPU out of memory
from tensorflow.keras import backend as K

# Reset Keras Session
def reset_keras():
    K.clear_session()
    gc.collect()

# Chatgpt wrote this imaging plot
def plot_error(train_accuracy, val_accuracy, text):
    epochs = range(1, len(train_accuracy) + 1)
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_accuracy, label='Training Accuracy', marker='o', linestyle='-', color='blue')
    plt.plot(epochs, val_accuracy, label='Validation Accuracy', marker='o', linestyle='-', color='red')

    # Loop through each epoch and add text annotation for training and validation accuracy
    for i, (train_acc, val_acc) in enumerate(zip(train_accuracy, val_accuracy)):
        plt.text(i + 1, train_acc, f'{train_acc:.2f}', ha='center', va='bottom')
        plt.text(i + 1, val_acc, f'{val_acc:.2f}', ha='center', va='top')
    
    title_string = text
    plt.title(title_string)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')  # Changed 'Loss' to 'Accuracy' as we are plotting accuracy values
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
model = prep_one_block()
start_time = timeit.default_timer()
_, history = run_model(model, .0005, X, y)
print(timeit.default_timer() - start_time)
text = "Learning Rate = .0005 Unrorated Images Hidden Layer: ReLU, Output Layer: Sigmoid"
plot_error(history.history["binary_accuracy"], history.history["val_binary_accuracy"], text)
model = None
reset_keras()
# Out:
# 129.8013832449999

# %%
model = prep_one_block()
start_time = timeit.default_timer()
_, history = run_model(model, .0005, X_rotated, y_rotated)
print(timeit.default_timer() - start_time)
text = "Learning Rate = .0005 Rotated Images Hidden Layer: ReLU, Output Layer: Sigmoid"
plot_error(history.history["binary_accuracy"], history.history["val_binary_accuracy"], text)
model = None
reset_keras()
# Out:
# 2024-03-26 20:18:36.417952: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 8651735040 exceeds 10% of free system memory.
# 2024-03-26 20:18:41.942115: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 8651735040 exceeds 10% of free system memory.
# 517.401882956

# %% [markdown]
# ## Initial Impressions
# .85 Validation with the unrotated images is ok.  With rotated Images, I'm getting .89. but after the 5-8th epoch, there is major overfitting.
#
# ## Testing different hidden layers and output layers
# I'm going to try this with different hidden layer options.  I'm testing all the hidden layers avaliable.  I also dropped the number of epochs to make more sense.

# %%
# Test different hidden layers
output_layers = ["Sigmoid", "Softmax", "Tanh", "PReLU"]
output_layer = ["Sigmoid"]
hidden_layers = ["PReLU"]
for hidden_layer in hidden_layers:
    dropout_value = .25
    inputs = keras.Input(shape=(32,32,3))
    convolution = inputs
    for i in range(0,1):
        convolution = convolution_block(convolution, 32, hidden_layer)
        convolution = convolution_block(convolution, 32, hidden_layer)
        convolution = pool_block(convolution)

    flatten= keras.layers.Flatten()(convolution)

    activation = flatten
    for i in range(0,1):
        activation = activation_block(activation,1024)
        activation = dropout_block(activation, dropout_value)
    outputs = keras.layers.Dense(1, activation="sigmoid")(activation)
    full_model = keras.Model(inputs, outputs)
    start_time = timeit.default_timer()
    
    
    _, history = run_model(full_model, .0005, X_rotated, y_rotated, epochs = 8)
    print(timeit.default_timer() - start_time)
    text = "Learning Rate = .0005 Unrorated Images Hidden Layer: " + hidden_layer + "Output Layer: " + output_layer
    plot_error(history.history["binary_accuracy"], history.history["val_binary_accuracy"], text)
    full_model = None
    reset_keras()
# Out:
# 2024-03-26 20:35:52.088592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.096522: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.096835: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.098579: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.098800: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.098945: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.309034: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.309245: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.309413: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 20:35:52.309542: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15520 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2024-03-26 20:35:56.314351: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 8651735040 exceeds 10% of free system memory.
# 2024-03-26 20:36:01.813936: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 8651735040 exceeds 10% of free system memory.
# 2024-03-26 20:36:06.732785: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-03-26 20:36:08.221151: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f5114002110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-26 20:36:08.221194: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2024-03-26 20:36:08.227872: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711485368.337030   14041 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 532.364067603

# %%
# Test different hidden layers

output_layers = ["Softmax", "Tanh", "PReLU"]
hidden_layer = "PReLU"
for output_layer in output_layers:
    dropout_value = .25
    inputs = keras.Input(shape=(32,32,3))
    convolution = inputs
    for i in range(0,1):
        convolution = convolution_block(convolution, 32, hidden_layer)
        convolution = convolution_block(convolution, 32, hidden_layer)
        convolution = pool_block(convolution)

    flatten= keras.layers.Flatten()(convolution)

    activation = flatten
    for i in range(0,1):
        activation = activation_block(activation,1024)
        activation = dropout_block(activation, dropout_value)
    outputs = keras.layers.Dense(1, activation=output_layer)(activation)
    full_model = keras.Model(inputs, outputs)
    start_time = timeit.default_timer()
    
    
    _, history = run_model(full_model, .0005, X_rotated, y_rotated)
    print(timeit.default_timer() - start_time)
    text = "Learning Rate = .0005 Unrorated Images Hidden Layer: " + hidden + "Output Layer: " + output_layer
    plot_error(history.history["binary_accuracy"], history.history["val_binary_accuracy"], text)
    full_model = None
    reset_keras()
# Out:
# 2024-03-26 20:49:52.022056: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 8651735040 exceeds 10% of free system memory.
# 2024-03-26 20:50:05.636869: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.06GiB (rounded to 8651735040)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-26 20:50:05.636912: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-26 20:50:05.636924: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 61, Chunks in use: 61. 15.2KiB allocated for chunks. 15.2KiB in use in bin. 2.0KiB client-requested in use in bin.
# 2024-03-26 20:50:05.636931: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.636938: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2024-03-26 20:50:05.636944: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 5, Chunks in use: 5. 17.5KiB allocated for chunks. 17.5KiB in use in bin. 16.9KiB client-requested in use in bin.
# 2024-03-26 20:50:05.636951: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 17, Chunks in use: 16. 82.2KiB allocated for chunks. 74.5KiB in use in bin. 62.8KiB client-requested in use in bin.
# 2024-03-26 20:50:05.636956: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.636962: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.636968: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 7, Chunks in use: 6. 318.8KiB allocated for chunks. 258.8KiB in use in bin. 216.0KiB client-requested in use in bin.
# 2024-03-26 20:50:05.636974: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 15, Chunks in use: 15. 1.51MiB allocated for chunks. 1.51MiB in use in bin. 1.47MiB client-requested in use in bin.
# 2024-03-26 20:50:05.636980: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 1, Chunks in use: 0. 237.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.636986: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 1, Chunks in use: 0. 390.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.636991: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.636997: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.34MiB allocated for chunks. 1.34MiB in use in bin. 1.34MiB client-requested in use in bin.
# 2024-03-26 20:50:05.637002: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 1, Chunks in use: 0. 2.27MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.637008: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 1, Chunks in use: 1. 5.37MiB allocated for chunks. 5.37MiB in use in bin. 5.37MiB client-requested in use in bin.
# 2024-03-26 20:50:05.637013: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.637020: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 5, Chunks in use: 5. 122.50MiB allocated for chunks. 122.50MiB in use in bin. 122.50MiB client-requested in use in bin.
# 2024-03-26 20:50:05.637031: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 3, Chunks in use: 2. 135.81MiB allocated for chunks. 86.81MiB in use in bin. 49.00MiB client-requested in use in bin.
# 2024-03-26 20:50:05.637036: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.637042: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-26 20:50:05.637048: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 3, Chunks in use: 2. 14.89GiB allocated for chunks. 10.07GiB in use in bin. 10.07GiB client-requested in use in bin.
# 2024-03-26 20:50:05.637054: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 8.06GiB was 256.00MiB, Chunk State:
# 2024-03-26 20:50:05.637065: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 4.82GiB | Requested Size: 8B | in_use: 0 | bin_num: 20, prev:   Size: 24.50MiB | Requested Size: 24.50MiB | in_use: 1 | bin_num: -1
# 2024-03-26 20:50:05.637070: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 16274030592
# 2024-03-26 20:50:05.637076: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000000 of size 1280 next 1
# 2024-03-26 20:50:05.637081: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000500 of size 256 next 2
# 2024-03-26 20:50:05.637086: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000600 of size 256 next 3
# 2024-03-26 20:50:05.637090: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000700 of size 256 next 5
# 2024-03-26 20:50:05.637095: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000800 of size 256 next 6
# 2024-03-26 20:50:05.637099: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000900 of size 256 next 7
# 2024-03-26 20:50:05.637103: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000a00 of size 256 next 10
# 2024-03-26 20:50:05.637108: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000b00 of size 256 next 13
# 2024-03-26 20:50:05.637112: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000c00 of size 256 next 12
# 2024-03-26 20:50:05.637116: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000d00 of size 256 next 16
# 2024-03-26 20:50:05.637121: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40000e00 of size 6144 next 8
# 2024-03-26 20:50:05.637127: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40002600 of size 3584 next 9
# 2024-03-26 20:50:05.637132: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40003400 of size 115200 next 4
# 2024-03-26 20:50:05.637136: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001f600 of size 256 next 19
# 2024-03-26 20:50:05.637141: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001f700 of size 256 next 17
# 2024-03-26 20:50:05.637145: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001f800 of size 256 next 22
# 2024-03-26 20:50:05.637149: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001f900 of size 256 next 23
# 2024-03-26 20:50:05.637154: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001fa00 of size 256 next 18
# 2024-03-26 20:50:05.637158: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001fb00 of size 256 next 24
# 2024-03-26 20:50:05.637162: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001fc00 of size 256 next 27
# 2024-03-26 20:50:05.637168: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001fd00 of size 256 next 28
# 2024-03-26 20:50:05.637172: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001fe00 of size 256 next 29
# 2024-03-26 20:50:05.637177: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4001ff00 of size 256 next 30
# 2024-03-26 20:50:05.637181: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40020000 of size 256 next 33
# 2024-03-26 20:50:05.637191: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40020100 of size 256 next 34
# 2024-03-26 20:50:05.637196: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40020200 of size 256 next 35
# 2024-03-26 20:50:05.637200: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40020300 of size 6144 next 25
# 2024-03-26 20:50:05.637205: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40021b00 of size 4096 next 26
# 2024-03-26 20:50:05.637210: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40022b00 of size 3584 next 36
# 2024-03-26 20:50:05.637214: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40023900 of size 256 next 37
# 2024-03-26 20:50:05.637219: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40023a00 of size 256 next 38
# 2024-03-26 20:50:05.637223: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40023b00 of size 56064 next 15
# 2024-03-26 20:50:05.637228: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40031600 of size 36864 next 14
# 2024-03-26 20:50:05.637232: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4003a600 of size 100352 next 11
# 2024-03-26 20:50:05.637237: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40052e00 of size 7168 next 60
# 2024-03-26 20:50:05.637242: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40054a00 of size 3584 next 59
# 2024-03-26 20:50:05.637246: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40055800 of size 115200 next 79
# 2024-03-26 20:50:05.637251: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40071a00 of size 3584 next 62
# 2024-03-26 20:50:05.637255: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40072800 of size 4608 next 89
# 2024-03-26 20:50:05.637259: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40073a00 of size 4096 next 88
# 2024-03-26 20:50:05.637264: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40074a00 of size 61440 next 55
# 2024-03-26 20:50:05.637269: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40083a00 of size 36864 next 56
# 2024-03-26 20:50:05.637273: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4008ca00 of size 100352 next 57
# 2024-03-26 20:50:05.637278: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d400a5200 of size 115200 next 86
# 2024-03-26 20:50:05.637282: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d400c1400 of size 115200 next 71
# 2024-03-26 20:50:05.637286: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d400dd600 of size 36864 next 85
# 2024-03-26 20:50:05.637291: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d400e6600 of size 100352 next 97
# 2024-03-26 20:50:05.637295: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d400fee00 of size 100352 next 102
# 2024-03-26 20:50:05.637299: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40117600 of size 4096 next 64
# 2024-03-26 20:50:05.637304: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40118600 of size 4096 next 74
# 2024-03-26 20:50:05.637308: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40119600 of size 4096 next 98
# 2024-03-26 20:50:05.637314: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4011a600 of size 4096 next 69
# 2024-03-26 20:50:05.637318: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7f4d4011b600 of size 399360 next 132
# 2024-03-26 20:50:05.637323: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4017ce00 of size 256 next 130
# 2024-03-26 20:50:05.637327: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4017cf00 of size 256 next 142
# 2024-03-26 20:50:05.637331: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4017d000 of size 256 next 138
# 2024-03-26 20:50:05.637336: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4017d100 of size 100352 next 78
# 2024-03-26 20:50:05.637340: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7f4d40195900 of size 242944 next 124
# 2024-03-26 20:50:05.637344: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d401d0e00 of size 256 next 108
# 2024-03-26 20:50:05.637349: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d401d0f00 of size 256 next 107
# 2024-03-26 20:50:05.637353: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d401d1000 of size 256 next 118
# 2024-03-26 20:50:05.637357: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d401d1100 of size 256 next 128
# 2024-03-26 20:50:05.637362: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d401d1200 of size 256 next 129
# 2024-03-26 20:50:05.637366: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d401d1300 of size 1408256 next 109
# 2024-03-26 20:50:05.637371: I external/local_tsl
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[12], line 25
#      21 full_model = keras.Model(inputs, outputs)
#      22 start_time = timeit.default_timer()
# ---> 25 _, history = run_model(full_model, .0005, X_rotated, y_rotated)
#      26 print(timeit.default_timer() - start_time)
#      27 text = "Learning Rate = .0005 Unrorated Images Hidden Layer: " + hidden + "Output Layer: " + output_layer
#
# Cell In[6], line 5, in run_model(full_model, learning_rate, X, y, epochs)
#       3 optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
#       4 full_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[keras.metrics.BinaryAccuracy()])
# ----> 5 history = full_model.fit(
#       6     x=X,
#       7     y=y,
#       8     batch_size=64,
#       9     epochs=epochs,
#      10     verbose=0,
#      11     callbacks=None,
#      12     validation_split=0.2,
#      13     validation_data=None,
#      14     shuffle=True,
#      15     class_weight=None,
#      16     sample_weight=None,
#      17     initial_epoch=0,
#      18     steps_per_epoch=None,
#      19     validation_steps=None,
#      20 validation_batch_size=None,
#      21 validation_freq=1,
#      22 )
#      23 return full_model, history
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:103, in convert_to_eager_tensor(value, ctx, dtype)
#     101     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102 ctx.ensure_initialized()
# --> 103 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
# /tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40329000 of size 7168 next 61
# 2024-03-26 20:50:05.637375: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4032ac00 of size 3584 next 103
# 2024-03-26 20:50:05.637379: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4032ba00 of size 115200 next 94
# 2024-03-26 20:50:05.637384: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40347c00 of size 256 next 125
# 2024-03-26 20:50:05.637388: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7f4d40347d00 of size 7936 next 100
# 2024-03-26 20:50:05.637392: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40349c00 of size 4096 next 53
# 2024-03-26 20:50:05.637397: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7f4d4034ac00 of size 61440 next 95
# 2024-03-26 20:50:05.637401: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40359c00 of size 72960 next 99
# 2024-03-26 20:50:05.637405: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4036b900 of size 256 next 122
# 2024-03-26 20:50:05.637410: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4036ba00 of size 256 next 105
# 2024-03-26 20:50:05.637414: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4036bb00 of size 256 next 117
# 2024-03-26 20:50:05.637418: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4036bc00 of size 256 next 127
# 2024-03-26 20:50:05.637423: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7f4d4036bd00 of size 2384896 next 32
# 2024-03-26 20:50:05.637427: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d405b2100 of size 115200 next 39
# 2024-03-26 20:50:05.637432: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d405ce300 of size 115200 next 40
# 2024-03-26 20:50:05.637436: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d405ea500 of size 36864 next 41
# 2024-03-26 20:50:05.637440: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d405f3500 of size 256 next 42
# 2024-03-26 20:50:05.637445: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d405f3600 of size 256 next 43
# 2024-03-26 20:50:05.637450: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d405f3700 of size 100352 next 44
# 2024-03-26 20:50:05.637455: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d4060bf00 of size 100352 next 45
# 2024-03-26 20:50:05.637459: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d40624700 of size 45278976 next 21
# 2024-03-26 20:50:05.637464: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d43152e00 of size 25690112 next 20
# 2024-03-26 20:50:05.637469: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4d449d2e00 of size 8651735040 next 31
# 2024-03-26 20:50:05.637473: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f484c2e00 of size 25690112 next 46
# 2024-03-26 20:50:05.637477: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d42e00 of size 4096 next 47
# 2024-03-26 20:50:05.637482: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d43e00 of size 4096 next 48
# 2024-03-26 20:50:05.637486: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d44e00 of size 4096 next 49
# 2024-03-26 20:50:05.637490: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d45e00 of size 4096 next 50
# 2024-03-26 20:50:05.637495: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d46e00 of size 256 next 51
# 2024-03-26 20:50:05.637499: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d46f00 of size 256 next 52
# 2024-03-26 20:50:05.637503: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47000 of size 256 next 58
# 2024-03-26 20:50:05.637508: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47100 of size 256 next 106
# 2024-03-26 20:50:05.637512: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47200 of size 256 next 76
# 2024-03-26 20:50:05.637516: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47300 of size 256 next 68
# 2024-03-26 20:50:05.637521: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47400 of size 256 next 96
# 2024-03-26 20:50:05.637525: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47500 of size 256 next 75
# 2024-03-26 20:50:05.637529: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47600 of size 256 next 101
# 2024-03-26 20:50:05.637534: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47700 of size 256 next 72
# 2024-03-26 20:50:05.637538: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47800 of size 256 next 84
# 2024-03-26 20:50:05.637542: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47900 of size 256 next 81
# 2024-03-26 20:50:05.637547: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47a00 of size 256 next 82
# 2024-03-26 20:50:05.637551: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47b00 of size 256 next 73
# 2024-03-26 20:50:05.637555: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47c00 of size 256 next 104
# 2024-03-26 20:50:05.637560: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47d00 of size 256 next 77
# 2024-03-26 20:50:05.637564: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47e00 of size 256 next 54
# 2024-03-26 20:50:05.637568: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d47f00 of size 256 next 67
# 2024-03-26 20:50:05.637573: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d48000 of size 256 next 90
# 2024-03-26 20:50:05.637577: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d48100 of size 256 next 65
# 2024-03-26 20:50:05.637581: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d48200 of size 256 next 92
# 2024-03-26 20:50:05.637587: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d48300 of size 256 next 93
# 2024-03-26 20:50:05.637591: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f49d48400 of size 5632768 next 87
# 2024-03-26 20:50:05.637599: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f4a2a7700 of size 45747456 next 63
# 2024-03-26 20:50:05.637604: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f4ce48400 of size 25690112 next 70
# 2024-03-26 20:50:05.637608: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f4e6c8400 of size 25690112 next 91
# 2024-03-26 20:50:05.637613: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4f4ff48400 of size 2162933760 next 120
# 2024-03-26 20:50:05.637617: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7f4fd0e04400 of size 51380224 next 115
# 2024-03-26 20:50:05.637622: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7f4fd3f04400 of size 25690112 next 126
# 2024-03-26 20:50:05.637626: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] Free  at 7f4fd5784400 of size 5176409088 next 18446744073709551615
# 2024-03-26 20:50:05.637631: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2024-03-26 20:50:05.637637: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 61 Chunks of size 256 totalling 15.2KiB
# 2024-03-26 20:50:05.637642: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1280 totalling 1.2KiB
# 2024-03-26 20:50:05.637647: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 3584 totalling 17.5KiB
# 2024-03-26 20:50:05.637652: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 11 Chunks of size 4096 totalling 44.0KiB
# 2024-03-26 20:50:05.637657: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4608 totalling 4.5KiB
# 2024-03-26 20:50:05.637662: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 6144 totalling 12.0KiB
# 2024-03-26 20:50:05.637667: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 7168 totalling 14.0KiB
# 2024-03-26 20:50:05.637672: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 36864 totalling 144.0KiB
# 2024-03-26 20:50:05.637677: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 56064 totalling 54.8KiB
# 2024-03-26 20:50:05.637682: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 61440 totalling 60.0KiB
# 2024-03-26 20:50:05.637687: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 72960 totalling 71.2KiB
# 2024-03-26 20:50:05.637692: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 100352 totalling 686.0KiB
# 2024-03-26 20:50:05.637698: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 115200 totalling 787.5KiB
# 2024-03-26 20:50:05.637702: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1408256 totalling 1.34MiB
# 2024-03-26 20:50:05.637707: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 5632768 totalling 5.37MiB
# 2024-03-26 20:50:05.637712: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 25690112 totalling 122.50MiB
# 2024-03-26 20:50:05.637718: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 45278976 totalling 43.18MiB
# 2024-03-26 20:50:05.637723: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 45747456 totalling 43.63MiB
# 2024-03-26 20:50:05.637728: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2162933760 totalling 2.01GiB
# 2024-03-26 20:50:05.637732: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 8651735040 totalling 8.06GiB
# 2024-03-26 20:50:05.637737: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 10.28GiB
# 2024-03-26 20:50:05.637744: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 16274030592 memory_limit_: 16274030592 available bytes: 0 curr_region_allocation_bytes_: 32548061184
# 2024-03-26 20:50:05.637754: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     16274030592
# InUse:                     11043144704
# MaxInUse:                  11141646848
# NumAllocs:                    13479447
# MaxAllocSize:               8651735040
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-26 20:50:05.637766: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] *********************************************************************_______________________________

# %% [markdown]
# ## Best Hidden and Output Layer
# I will continue with PReLU.  PReL
# ## Number of convolutional layers
# There is a upper bound on the number of convolutional layers.  This is due to the very small size of the images.

# %%
# Convolutional layers
learning_rate = .0005
conv = 2
dropout_value = .25
inputs = keras.Input(shape=(32,32,3))
convolution = inputs
for i in range(0,conv):
    convolution = convolution_block(convolution, 32)
    convolution = convolution_block(convolution, 32)
    convolution = pool_block(convolution)
flatten= keras.layers.Flatten()(convolution)
activation = flatten
for i in range(0,1):
    activation = activation_block(activation,1024)
    activation = dropout_block(activation, dropout_value)
    
outputs = keras.layers.Dense(1, activation="sigmoid")(activation)
full_model = keras.Model(inputs, outputs)

text = "Number of Convolutional Layers: " + str(conv) + " Learning Rate: " + str(learning_rate)
print(text)

_, history = run_model(full_model, learning_rate)
plot_error(history.history["binary_accuracy"], history.history["val_binary_accuracy"], text)
full_model = None
reset_keras()
# Out:
# Number of Convolutional Layers: 2 Learning Rate: 0.00025
# Epoch 1/10
# 2751/2751 - 14s - loss: 0.6391 - binary_accuracy: 0.6205 - val_loss: 0.6016 - val_binary_accuracy: 0.6684 - 14s/epoch - 5ms/step
# Epoch 2/10
# 2751/2751 - 11s - loss: 0.5826 - binary_accuracy: 0.6829 - val_loss: 0.5720 - val_binary_accuracy: 0.6953 - 11s/epoch - 4ms/step
# Epoch 3/10
# 2751/2751 - 11s - loss: 0.5633 - binary_accuracy: 0.7078 - val_loss: 0.5521 - val_binary_accuracy: 0.7197 - 11s/epoch - 4ms/step
# Epoch 4/10
# 2751/2751 - 11s - loss: 0.5420 - binary_accuracy: 0.7291 - val_loss: 0.5305 - val_binary_accuracy: 0.7422 - 11s/epoch - 4ms/step
# Epoch 5/10
# 2751/2751 - 11s - loss: 0.5113 - binary_accuracy: 0.7554 - val_loss: 0.4835 - val_binary_accuracy: 0.7772 - 11s/epoch - 4ms/step
# Epoch 6/10
# 2751/2751 - 11s - loss: 0.4727 - binary_accuracy: 0.7827 - val_loss: 0.4574 - val_binary_accuracy: 0.7926 - 11s/epoch - 4ms/step
# Epoch 7/10
# 2751/2751 - 11s - loss: 0.4580 - binary_accuracy: 0.7910 - val_loss: 0.4699 - val_binary_accuracy: 0.7840 - 11s/epoch - 4ms/step
# Epoch 8/10
# 2751/2751 - 11s - loss: 0.4516 - binary_accuracy: 0.7954 - val_loss: 0.4438 - val_binary_accuracy: 0.7996 - 11s/epoch - 4ms/step
# Epoch 9/10
# 2751/2751 - 12s - loss: 0.4467 - binary_accuracy: 0.7976 - val_loss: 0.4379 - val_binary_accuracy: 0.8021 - 12s/epoch - 4ms/step
# Epoch 10/10
# 2751/2751 - 11s - loss: 0.4425 - binary_accuracy: 0.7996 - val_loss: 0.4361 - val_binary_accuracy: 0.8029 - 11s/epoch - 4ms/step

# %% [markdown]
# ## Results
# .82 is an improvement.  I had to immidiatly update my target learning rate.  The increased model component definitly affected the outcome.
#
# ## Tuning Dense Blocks
# The dense blocks are the meat of the learning process.  I have to be carefull to have enough to make a desicion but not too many as to prevent overfitting.  Part of this will be to tune the dropout rate of the dense blocks.
#
# I hav chosen to do 2 blocks of 1024 or 32x32 bits and 1 of 256 bits.  I'm expecting wild overfitting.

# %%
# Convolutional layers
learning_rate = .0005
conv = 2
dropout_value = .25
inputs = keras.Input(shape=(32,32,3))
convolution = inputs
#Load the convolution and pool actions
for i in range(0,conv):
    convolution = convolution_block(convolution, 32)
    convolution = convolution_block(convolution, 32)
    convolution = pool_block(convolution)
flatten= keras.layers.Flatten()(convolution)
activation = flatten
# run 3 Dense Blocks with a 25% dropout rate  The first 2 dense blocks are 1024 or 32x32.  The final is 256.  
activation = activation_block(activation,1024)
dropout = dropout_block(activation, dropout_value)

activation = activation_block(dropout,1024)
dropout = dropout_block(activation, dropout_value)

activation = activation_block(dropout,256)
dropout = dropout_block(activation, dropout_value)

outputs = keras.layers.Dense(1, activation="sigmoid")(dropout)
full_model = keras.Model(inputs, outputs)

text = "Number of Convolutional Layers: " + str(conv) + " Learning Rate: " + str(learning_rate)
print(text)

_, history = run_model(full_model, learning_rate)
plot_error(history.history["binary_accuracy"], history.history["val_binary_accuracy"], text)
reset_keras()
# Out:
# 2024-03-20 20:39:59.065912: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.246272: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.246518: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.248219: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.248506: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.248679: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.592312: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.592568: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.592756: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-20 20:39:59.592908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14792 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0
# Number of Convolutional Layers: 2 Learning Rate: 0.00025
# Epoch 1/10
# 2024-03-20 20:40:04.839455: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-03-20 20:40:07.860366: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f06bd53c800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-20 20:40:07.860402: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2024-03-20 20:40:07.888480: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710967208.041853    4345 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2751/2751 - 21s - loss: 0.6365 - binary_accuracy: 0.6271 - val_loss: 0.5862 - val_binary_accuracy: 0.6773 - 21s/epoch - 8ms/step
# Epoch 2/10
# 2751/2751 - 13s - loss: 0.5824 - binary_accuracy: 0.6848 - val_loss: 0.5709 - val_binary_accuracy: 0.6972 - 13s/epoch - 5ms/step
# Epoch 3/10
# 2751/2751 - 13s - loss: 0.5678 - binary_accuracy: 0.7029 - val_loss: 0.5587 - val_binary_accuracy: 0.7131 - 13s/epoch - 5ms/step
# Epoch 4/10
# 2751/2751 - 13s - loss: 0.5490 - binary_accuracy: 0.7219 - val_loss: 0.5399 - val_binary_accuracy: 0.7306 - 13s/epoch - 5ms/step
# Epoch 5/10
# 2751/2751 - 13s - loss: 0.5157 - binary_accuracy: 0.7502 - val_loss: 0.4725 - val_binary_accuracy: 0.7812 - 13s/epoch - 5ms/step
# Epoch 6/10
# 2751/2751 - 13s - loss: 0.4710 - binary_accuracy: 0.7819 - val_loss: 0.4558 - val_binary_accuracy: 0.7905 - 13s/epoch - 5ms/step
# Epoch 7/10
# 2751/2751 - 13s - loss: 0.4600 - binary_accuracy: 0.7891 - val_loss: 0.4640 - val_binary_accuracy: 0.7844 - 13s/epoch - 5ms/step
# Epoch 8/10
# 2751/2751 - 13s - loss: 0.4544 - binary_accuracy: 0.7913 - val_loss: 0.4577 - val_binary_accuracy: 0.7878 - 13s/epoch - 5ms/step
# Epoch 9/10
# 2751/2751 - 14s - loss: 0.4504 - binary_accuracy: 0.7937 - val_loss: 0.4467 - val_binary_accuracy: 0.7973 - 14s/epoch - 5ms/step
# Epoch 10/10
# 2751/2751 - 13s - loss: 0.4479 - binary_accuracy: 0.7959 - val_loss: 0.4506 - val_binary_accuracy: 0.7975 - 13s/epoch - 5ms/step

# %% [markdown]
# This is a supprise.  This caused a net decrease in the accuracy.  I also didn't see the high level of overfitting I expected.
#
# ## I'm going to try increasing the dropout rate and dropping the learning rate.
# I'm going to try to tune the number of filters in each layer of the Conv-Conv-Pool cycle.  I'll start with 64 convolution filters.

# %%
# Convolutional layers
learning_rate = .0001
conv = 2
dropout_value = .25
inputs = keras.Input(shape=(32,32,3))
convolution = inputs
#First Convolution Cycle
convolution = convolution_block(convolution, 64)
convolution = convolution_block(convolution, 64)
convolution = pool_block(convolution)

#Second Convolution Cycle
convolution = convolution_block(convolution, 64)
convolution = convolution_block(convolution, 64)
convolution = pool_block(convolution)

flatten= keras.layers.Flatten()(convolution)
activation = flatten

# Run Dense Blocks
activation = activation_block(activation,1024)
dropout = dropout_block(activation, dropout_value)

outputs = keras.layers.Dense(1, activation="sigmoid")(dropout)
full_model = keras.Model(inputs, outputs)

text = "Number of Convolutional Layers: " + str(conv) + " Learning Rate: " + str(learning_rate)
print(text)

_, history = run_model(full_model, learning_rate)
plot_error(history.history["binary_accuracy"], history.history["val_binary_accuracy"], text)
reset_keras()
# Out:
# Number of Convolutional Layers: 2 Learning Rate: 0.0001
# Epoch 1/10
# 2751/2751 - 16s - loss: 0.6612 - binary_accuracy: 0.6027 - val_loss: 0.5984 - val_binary_accuracy: 0.6652 - 16s/epoch - 6ms/step
# Epoch 2/10
# 2751/2751 - 13s - loss: 0.5916 - binary_accuracy: 0.6708 - val_loss: 0.5844 - val_binary_accuracy: 0.6805 - 13s/epoch - 5ms/step
# Epoch 3/10
# 2751/2751 - 13s - loss: 0.5794 - binary_accuracy: 0.6860 - val_loss: 0.5731 - val_binary_accuracy: 0.6925 - 13s/epoch - 5ms/step
# Epoch 4/10
# 2751/2751 - 13s - loss: 0.5711 - binary_accuracy: 0.6966 - val_loss: 0.5666 - val_binary_accuracy: 0.6998 - 13s/epoch - 5ms/step
# Epoch 5/10
# 2751/2751 - 13s - loss: 0.5626 - binary_accuracy: 0.7066 - val_loss: 0.5651 - val_binary_accuracy: 0.7059 - 13s/epoch - 5ms/step
# Epoch 6/10
# 2751/2751 - 13s - loss: 0.5522 - binary_accuracy: 0.7177 - val_loss: 0.5490 - val_binary_accuracy: 0.7208 - 13s/epoch - 5ms/step
# Epoch 7/10
# 2751/2751 - 13s - loss: 0.5371 - binary_accuracy: 0.7322 - val_loss: 0.5253 - val_binary_accuracy: 0.7390 - 13s/epoch - 5ms/step
# Epoch 8/10
# 2751/2751 - 13s - loss: 0.5114 - binary_accuracy: 0.7529 - val_loss: 0.4888 - val_binary_accuracy: 0.7713 - 13s/epoch - 5ms/step
# Epoch 9/10
# 2751/2751 - 13s - loss: 0.4829 - binary_accuracy: 0.7747 - val_loss: 0.4802 - val_binary_accuracy: 0.7755 - 13s/epoch - 5ms/step
# Epoch 10/10
# 2751/2751 - 13s - loss: 0.4688 - binary_accuracy: 0.7846 - val_loss: 0.4799 - val_binary_accuracy: 0.7819 - 13s/epoch - 5ms/step

# %% [markdown]
# ## More Dropout layers
# Ok, back from scratch to try other things.  I'll now try other
